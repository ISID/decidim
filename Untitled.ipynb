# %%
import yaml
with open('config/locales/ja.yml', 'r') as yml:
    config = yaml.load(yml)
# Out:
# <ipython-input-3-4466b0546c12>:3: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   config = yaml.load(yml)
